# %%
#BAITAPCHUONG1
print('Hello World!')
# Out:
# Hello World!

# %%
# Cau 6
print("Minh về minh có nhớ ta?\nMười lăm năm ấy thiết tha mặn nồng.\nMình về mình có nhớ không?\nNhìn cây nhớ núi, nhìn sông nhớ nguồn.")
# Out:
# Minh về minh có nhớ ta?
# Mười lăm năm ấy thiết tha mặn nồng.
# Mình về mình có nhớ không?
# Nhìn cây nhớ núi, nhìn sông nhớ nguồn.

# %%
print('Albert Einstein đã tường nói: Một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.')
# Out:
# Albert Einstein đã tường nói: Một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.

# %%
if 5 > 2:
    print('Five is greater than two!')
# Out:
# Five is greater than two!

# %%
total = 1 + \
2 + \
3
print(total); print('Hello Python!')
# Out:
# 6
# Hello Python!

# %%
if True:
    print('True')
else:
    print('False')
# Out:
# True

# %%
#This is a comment
print('Hello World!')
# Out:
# Hello World!

# %%
import math
import os

# %%
def add(a, b):
    result = a + b
    return result

# %%
# Cau 7
import sys
print("Số tham số:", len(sys.argv), "tham số.")
print("Danh sách tham số:", str(sys.argv))
# Out:
# Số tham số: 2 tham số.
# Danh sách tham số: ['C:\\Users\\DELL\\AppData\\Roaming\\Python\\Python313\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\DELL\\AppData\\Roaming\\jupyter\\runtime\\kernel-v30939532175ec0d3cc5af03fcb6490b53a9d008e7.json']

# %%
# Cau 8
print("* * * *\n")
print("*     *\n")
print("*     *\n")
print("* * * *")
# Out:
# * * * *
#
# *     *
#
# *     *
#
# * * * *

# %%
# cau 9
for i in range(4):
    print("*" * 9,"\n")
# Out:
# *********
#
# *********
#
# *********
#
# *********

# %%
# Cau 10
print("    *")
print("   ***")
print("  *****")
print("   ***")
print("  *****")
print(" *******")
print("*********")
print("  *  *")
print("  *  *")
# Out:
#     *
#    ***
#   *****
#    ***
#   *****
#  *******
# *********
#   *  *
#   *  *
